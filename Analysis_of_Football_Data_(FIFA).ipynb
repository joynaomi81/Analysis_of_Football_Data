# %% [markdown]
# <a href="https://colab.research.google.com/github/joynaomi81/Joynaomi81/blob/main/Analysis_of_Football_Data_(FIFA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset1/players_fifa22.csv')

# %%
fifa=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset1/players_fifa22.csv')

# %%
fifa.head()
# Out:
#        ID               Name                      FullName  Age  Height  \
# 0  158023           L. Messi                  Lionel Messi   34     170
# 1  188545     R. Lewandowski            Robert Lewandowski   32     185
# 2   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3  231747          K. Mbappé                 Kylian Mbappé   22     182
# 4  200389           J. Oblak                     Jan Oblak   28     188
#
#    Weight                                          PhotoUrl Nationality  \
# 0      72  https://cdn.sofifa.com/players/158/023/22_60.png   Argentina
# 1      81  https://cdn.sofifa.com/players/188/545/22_60.png      Poland
# 2      83  https://cdn.sofifa.com/players/020/801/22_60.png    Portugal
# 3      73  https://cdn.sofifa.com/players/231/747/22_60.png      France
# 4      87  https://cdn.sofifa.com/players/200/389/22_60.png    Slovenia
#
#    Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# ...

# %%
print('Number of rows:',df.shape[0])
# Out:
# Number of rows: 19260

# %%
print('Column names:', df.columns.tolist())
# Out:
# Column names: ['ID', 'Name', 'FullName', 'Age', 'Height', 'Weight', 'PhotoUrl', 'Nationality', 'Overall', 'Potential', 'Growth', 'TotalStats', 'BaseStats', 'Positions', 'BestPosition', 'Club', 'ValueEUR', 'WageEUR', 'ReleaseClause', 'ClubPosition', 'ContractUntil', 'ClubNumber', 'ClubJoined', 'OnLoad', 'NationalTeam', 'NationalPosition', 'NationalNumber', 'PreferredFoot', 'IntReputation', 'WeakFoot', 'SkillMoves', 'AttackingWorkRate', 'DefensiveWorkRate', 'PaceTotal', 'ShootingTotal', 'PassingTotal', 'DribblingTotal', 'DefendingTotal', 'PhysicalityTotal', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPos
# ...

# %%
for col in fifa.columns:
  print(col)
# Out:
# ID
# Name
# FullName
# Age
# Height
# Weight
# PhotoUrl
# Nationality
# Overall
# Potential
# Growth
# TotalStats
# BaseStats
# Positions
# BestPosition
# Club
# ValueEUR
# WageEUR
# ReleaseClause
# ClubPosition
# ContractUntil
# ClubNumber
# ClubJoined
# OnLoad
# NationalTeam
# NationalPosition
# NationalNumber
# PreferredFoot
# IntReputation
# WeakFoot
# SkillMoves
# AttackingWorkRate
# DefensiveWorkRate
# PaceTotal
# ShootingTotal
# PassingTotal
# DribblingTotal
# DefendingTotal
# PhysicalityTotal
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# STRating
# LWRating
# LFRating
# CFRating
# RFRating
# ...

# %%
fifa.shape
# Out:
# (19260, 90)

# %%
fifa['Nationality'].value_counts()
# Out:
# England      1718
# Germany      1214
# Spain        1091
# France        987
# Argentina     955
#              ...
# Tanzania        1
# Fiji            1
# Bermuda         1
# Malawi          1
# Indonesia       1
# Name: Nationality, Length: 163, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:10]
# Out:
# England          1718
# Germany          1214
# Spain            1091
# France            987
# Argentina         955
# Brazil            913
# Japan             544
# Netherlands       439
# United States     411
# Poland            403
# Name: Nationality, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:5]
# Out:
# England      1718
# Germany      1214
# Spain        1091
# France        987
# Argentina     955
# Name: Nationality, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize=(8,5))
plt.bar(list(fifa['Nationality'].value_counts()[0:5].keys()),list(fifa['Nationality'].value_counts()[0:5]),color='r')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar(list(fifa['Positions'].value_counts()[0:5].keys()),list(fifa['Positions'].value_counts()[0:5]),color='y')
plt.show()

# %%
player_salary = fifa[['Name','WageEUR']]

# %%
player_salary.head()
# Out:
#                 Name  WageEUR
# 0           L. Messi   320000
# 1     R. Lewandowski   270000
# 2  Cristiano Ronaldo   270000
# 3          K. Mbappé   230000
# 4           J. Oblak   130000

# %%
player_salary=player_salary.sort_values(by=['WageEUR'],ascending=False)

# %%
player_salary.head()
# Out:
#             Name  WageEUR
# 13    K. Benzema   350000
# 5   K. De Bruyne   350000
# 0       L. Messi   320000
# 25      T. Kroos   310000
# 12      Casemiro   310000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(fifa['Name'].value_counts()[0:5].keys()),list(fifa['WageEUR'].value_counts()[0:5]),color='b')
plt.show()

# %%
fifa['Nationality']=='England'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19255    False
# 19256    False
# 19257    False
# 19258    False
# 19259    False
# Name: Nationality, Length: 19260, dtype: bool

# %%
England=fifa[fifa['Nationality']=='England']
England.head(15)
# Out:
#          ID                 Name                FullName  Age  Height  Weight  \
# 8    202126              H. Kane              Harry Kane   27     188      89
# 29   202652          R. Sterling         Raheem Sterling   26     170      69
# 42   231281  T. Alexander-Arnold  Trent Alexander-Arnold   22     180      69
# 46   233049            J. Sancho            Jadon Sancho   21     180      76
# 63   208830             J. Vardy             Jamie Vardy   34     179      74
# 82   188377            K. Walker             Kyle Walker   31     183      83
# 90   231677          M. Rashford         Marcus Rashford   23     186      70
# 102  237692             P. Foden              Phil Foden   21     171      69
# 106  203263           H. Maguire           Harry Maguire   28     194     100
# 109  186345          K. Trippier         Kieran Trippier   30     173      69
# 111  183711         J. Henderson        Jordan Henderson   31     182      80
# ...

# %%
England.sort_values(by=['Weight'],ascending=False).head()
# Out:
#            ID          Name           FullName  Age  Height  Weight  \
# 11061  156321  A. Akinfenwa  Adebayo Akinfenwa   39     178     110
# 8013   202123      C. Aneke        Chuks Aneke   27     191     100
# 106    203263    H. Maguire      Harry Maguire   28     194     100
# 4689   163600      J. Ruddy         John Ruddy   34     193      97
# 14033  202770     C. Ripley      Connor Ripley   28     191      96
#
#                                                PhotoUrl Nationality  Overall  \
# 11061  https://cdn.sofifa.com/players/156/321/22_60.png     England       65
# 8013   https://cdn.sofifa.com/players/202/123/22_60.png     England       67
# 106    https://cdn.sofifa.com/players/203/263/22_60.png     England       84
# 4689   https://cdn.sofifa.com/players/163/600/22_60.png     England       70
# 14033  https://cdn.sofifa.com/players/202/770/22_60.png     England       62
#
#        Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# ...

# %%
England.sort_values(by=['Height'],ascending=False).head()
# Out:
#            ID         Name        FullName  Age  Height  Weight  \
# 15341  215408   A. Chapman   Aaron Chapman   31     203      92
# 16620  251453   D. Langley     Dan Langley   20     201      80
# 1893   172203   F. Forster  Fraser Forster   33     201      93
# 5489   204846  J. Blackman  Jamal Blackman   27     199      93
# 13618  232174   O. Hawkins  Oliver Hawkins   29     199      92
#
#                                                PhotoUrl Nationality  Overall  \
# 15341  https://cdn.sofifa.com/players/215/408/22_60.png     England       60
# 16620  https://cdn.sofifa.com/players/251/453/22_60.png     England       58
# 1893   https://cdn.sofifa.com/players/172/203/22_60.png     England       75
# 5489   https://cdn.sofifa.com/players/204/846/22_60.png     England       69
# 13618  https://cdn.sofifa.com/players/232/174/22_60.png     England       62
#
#        Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# ...

# %%
 fifa[['Name','Club']]
# Out:
#                     Name                               Club
# 0               L. Messi                Paris Saint-Germain
# 1         R. Lewandowski                  FC Bayern München
# 2      Cristiano Ronaldo                  Manchester United
# 3              K. Mbappé                Paris Saint-Germain
# 4               J. Oblak                 Atlético de Madrid
# ...                  ...                                ...
# 19255           S. Black                         Finn Harps
# 19256            Ma Zhen                Shanghai Shenhua FC
# 19257         Yang Haoyu  Dalian Professional Football Club
# 19258           He Siwei      Chongqing Liangjiang Athletic
# 19259      Chen Guoliang                        Shenzhen FC
#
# [19260 rows x 2 columns]

# %%
fifa[['FullName']]
# Out:
#                            FullName
# 0                      Lionel Messi
# 1                Robert Lewandowski
# 2      C. Ronaldo dos Santos Aveiro
# 3                     Kylian Mbappé
# 4                         Jan Oblak
# ...                             ...
# 19255                 Stephen Black
# 19256                       Zhen Ma
# 19257                    Haoyu Yang
# 19258                      Siwei He
# 19259                 Guoliang Chen
#
# [19260 rows x 1 columns]

# %%
fifa[['Name','BaseStats']]
# Out:
#                     Name  BaseStats
# 0               L. Messi        462
# 1         R. Lewandowski        460
# 2      Cristiano Ronaldo        457
# 3              K. Mbappé        470
# 4               J. Oblak        489
# ...                  ...        ...
# 19255           S. Black        246
# 19256            Ma Zhen        285
# 19257         Yang Haoyu        247
# 19258           He Siwei        250
# 19259      Chen Guoliang        245
#
# [19260 rows x 2 columns]

# %%
England.sort_values(by=['WageEUR'],ascending=False).head()
# Out:
#          ID         Name         FullName  Age  Height  Weight  \
# 29   202652  R. Sterling  Raheem Sterling   26     170      69
# 8    202126      H. Kane       Harry Kane   27     188      89
# 121  206517  J. Grealish    Jack Grealish   25     180      81
# 63   208830     J. Vardy      Jamie Vardy   34     179      74
# 82   188377    K. Walker      Kyle Walker   31     183      83
#
#                                              PhotoUrl Nationality  Overall  \
# 29   https://cdn.sofifa.com/players/202/652/22_60.png     England       88
# 8    https://cdn.sofifa.com/players/202/126/22_60.png     England       90
# 121  https://cdn.sofifa.com/players/206/517/22_60.png     England       84
# 63   https://cdn.sofifa.com/players/208/830/22_60.png     England       86
# 82   https://cdn.sofifa.com/players/188/377/22_60.png     England       85
#
#      Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# ...

# %%
fifa['Nationality']=='Spain'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19255    False
# 19256    False
# 19257    False
# 19258    False
# 19259    False
# Name: Nationality, Length: 19260, dtype: bool

# %%
Spain=fifa[fifa['Nationality']=='Spain']
Spain.head(10)
# Out:
#         ID             Name                    FullName  Age  Height  Weight  \
# 23  155862     Sergio Ramos         Sergio Ramos García   35     184      82
# 52  189513           Parejo         Daniel Parejo Muñoz   32     182      74
# 53  189511  Sergio Busquets      Sergio Busquets Burgos   32     189      76
# 54  189509           Thiago            Thiago Alcântara   30     174      70
# 55  189332       Jordi Alba            Jordi Alba Ramos   32     170      68
# 59  231866            Rodri  Rodrigo Hernández Cascante   25     191      82
# 60  226161  Marcos Llorente      Marcos Llorente Moreno   26     184      74
# 62  208093    Gerard Moreno     Gerard Moreno Balagueró   29     180      77
# 65  212218       A. Laporte             Aymeric Laporte   27     191      85
# 75  168542      David Silva   David Josué Jiménez Silva   35     173      67
#
#                                             PhotoUrl Nationality  Overall  \
# ...

# %%
Spain.sort_values(by=['Weight'],ascending=False).head()
# Out:
#           ID            Name                 FullName  Age  Height  Weight  \
# 2383  183666         Roberto     Roberto Jiménez Gago   35     192      96
# 4491  189709          Alcalá     Pedro Alcalá Guirado   32     196      93
# 4578  186680  Raúl Fernández  Raúl Fdez-Cavada Mateos   33     195      92
# 663    24630      Pepe Reina   José Manuel Reina Páez   38     188      92
# 7034  253455   Sergio Castel   Sergio Castel Martínez   26     188      90
#
#                                               PhotoUrl Nationality  Overall  \
# 2383  https://cdn.sofifa.com/players/183/666/22_60.png       Spain       74
# 4491  https://cdn.sofifa.com/players/189/709/22_60.png       Spain       71
# 4578  https://cdn.sofifa.com/players/186/680/22_60.png       Spain       71
# 663   https://cdn.sofifa.com/players/024/630/22_60.png       Spain       78
# 7034  https://cdn.sofifa.com/players/253/455/22_60.png       Spain       68
#
# ...

# %%
Spain.sort_values(by=['Height'],ascending=False).head()
# Out:
#            ID            Name                   FullName  Age  Height  Weight  \
# 11301  264387           Pedro         Pedro Ruiz Delgado   21     198      89
# 1285   228789  Robert Sanchéz       Robert Lynch Sanchéz   23     197      85
# 1035   206652     Sergio Rico       Sergio Rico González   27     196      90
# 11126  243587    Fran Vieites  Francisco Barbosa Vieites   22     196      88
# 925    146748     Diego López      Diego López Rodríguez   39     196      89
#
#                                                PhotoUrl Nationality  Overall  \
# 11301  https://cdn.sofifa.com/players/264/387/22_60.png       Spain       64
# 1285   https://cdn.sofifa.com/players/228/789/22_60.png       Spain       76
# 1035   https://cdn.sofifa.com/players/206/652/22_60.png       Spain       77
# 11126  https://cdn.sofifa.com/players/243/587/22_60.png       Spain       64
# 925    https://cdn.sofifa.com/players/146/748/22_60.png       Spain       77
#
# ...

# %%
player_Shooting= fifa[['Name','ShootingTotal']]

# %%
player_Shooting.sort_values(by=['ShootingTotal'],ascending=False).head()
# Out:
#                 Name  ShootingTotal
# 2  Cristiano Ronaldo             94
# 0           L. Messi             92
# 4           J. Oblak             92
# 1     R. Lewandowski             92
# 8            H. Kane             91

# %%
player_Best= fifa[['Name','BestPosition']]

# %%
player_Best.sort_values(by=['BestPosition'],ascending=False).head()
# Out:
#                 Name BestPosition
# 11061   A. Akinfenwa           ST
# 9015      L. Iberico           ST
# 9004   M. Tchokounté           ST
# 8995        B. Rubio           ST
# 8987       M. Donoso           ST

# %%
player_defending= fifa[['Name','DefendingTotal','Nationality','Club']]

# %%
player_defending.sort_values(by=['DefendingTotal'],ascending=False).head()
# Out:
#             Name  DefendingTotal  Nationality                 Club
# 16   V. van Dijk              91  Netherlands            Liverpool
# 56    M. Hummels              89      Germany    Borussia Dortmund
# 57  G. Chiellini              89        Italy             Juventus
# 38    Marquinhos              89       Brazil  Paris Saint-Germain
# 43    Rúben Dias              88     Portugal      Manchester City

# %%
Chelsea=fifa[fifa['Club']=='Chelsea']

# %%
Chelsea.sort_values(by=['WageEUR'],ascending=False).head()
# Out:
#          ID       Name                 FullName  Age  Height  Weight  \
# 22   192505  R. Lukaku            Romelu Lukaku   28     191      94
# 7    215914   N. Kanté             N'Golo Kanté   30     168      70
# 95   205498   Jorginho  Luiz Frello Filho Jorge   29     180      68
# 134  208670  H. Ziyech             Hakim Ziyech   28     181      65
# 137  212188  T. Werner              Timo Werner   25     180      76
#
#                                              PhotoUrl Nationality  Overall  \
# 22   https://cdn.sofifa.com/players/192/505/22_60.png     Belgium       88
# 7    https://cdn.sofifa.com/players/215/914/22_60.png      France       90
# 95   https://cdn.sofifa.com/players/205/498/22_60.png       Italy       85
# 134  https://cdn.sofifa.com/players/208/670/22_60.png     Morocco       84
# 137  https://cdn.sofifa.com/players/212/188/22_60.png     Germany       84
#
#      Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# ...

# %%
Chelsea.sort_values(by=['ShootingTotal'],ascending=False).head()
# Out:
#          ID        Name       FullName  Age  Height  Weight  \
# 22   192505   R. Lukaku  Romelu Lukaku   28     191      94
# 176  234642    E. Mendy  Édouard Mendy   29     197      86
# 137  212188   T. Werner    Timo Werner   25     180      76
# 177  233064    M. Mount    Mason Mount   22     178      70
# 117  235790  K. Havertz    Kai Havertz   22     188      82
#
#                                              PhotoUrl Nationality  Overall  \
# 22   https://cdn.sofifa.com/players/192/505/22_60.png     Belgium       88
# 176  https://cdn.sofifa.com/players/234/642/22_60.png     Senegal       83
# 137  https://cdn.sofifa.com/players/212/188/22_60.png     Germany       84
# 177  https://cdn.sofifa.com/players/233/064/22_60.png     England       83
# 117  https://cdn.sofifa.com/players/235/790/22_60.png     Germany       84
#
#      Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# 22          88  ...        83        77        83        64        62
# ...

# %%
Liverpool=fifa[fifa['Club']=='Liverpool']

# %%
Liverpool.sort_values(by=['TotalStats'],ascending=False).head()
# Out:
#          ID                 Name                FullName  Age  Height  Weight  \
# 42   231281  T. Alexander-Arnold  Trent Alexander-Arnold   22     180      69
# 18   209331             M. Salah           Mohamed Salah   29     175      71
# 54   189509               Thiago        Thiago Alcântara   30     174      70
# 111  183711         J. Henderson        Jordan Henderson   31     182      80
# 15   208722              S. Mané              Sadio Mané   29     175      69
#
#                                              PhotoUrl Nationality  Overall  \
# 42   https://cdn.sofifa.com/players/231/281/22_60.png     England       87
# 18   https://cdn.sofifa.com/players/209/331/22_60.png       Egypt       89
# 54   https://cdn.sofifa.com/players/189/509/22_60.png       Spain       86
# 111  https://cdn.sofifa.com/players/183/711/22_60.png     England       84
# 15   https://cdn.sofifa.com/players/208/722/22_60.png     Senegal       89
#
# ...
